# %%
#to convert the segmented images to binary
import cv2
import os
import imageio
path='data/segment/'
path1='data/segment_binary/'
for i in range(51):
    img = cv2. imread(path + str(i) + '(1).png',2)
    ret, bw_img = cv2. threshold(img,127,255,cv2. THRESH_BINARY)
    #cv2. imshow("Binary Image",bw_img)
    imageio.imwrite(path1 + str(i) + '(ff).png',bw_img)
    #cv2. waitKey(0)
    #cv2. destroyAllWindows()

# %%
#To convert the ground truth test images to binary
from PIL import Image
path='data/groundTruthTest/'
path2='data/resize/'
for i in range(51):
    img=cv2.imread(path+str(i)+'_expert.bmp',2)
    ret, bw_img = cv2.threshold(img,0,255,cv2. THRESH_BINARY)
    imageio.imwrite(path2 + str(i) + '.png',bw_img)
