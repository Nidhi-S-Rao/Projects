# %%
#Find dice coefficient
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
total=0
np.set_printoptions(threshold=np.inf)
for i in range(51):
    
    
    
    
    img1=plt.imread('data/resize/'+str(i)+'.png')
    img1=np.asarray(img1)
    #print(img1)
    img1=np.where(img1<0.9,0,1)
    #img1=img1.astype(np.bool)
    #print(img1)
    #print(img1.shape)
  
    img2=plt.imread('data/segment_binary/'+str(i)+'(ff).png')
    img2=np.asarray(img2)
    img2=np.where(img2<0.9,0,1)
    #print(img2)
    #img2=img2.astype(np.bool)
    #print(img2)
    #print(img2.shape)


    intersection = np.logical_and(img1, img2)
    val= 2. * intersection.sum() / (img1.sum() + img2.sum())
    print(i,val)
    total=total+val
    
print("Dice coeff=",(total/51))
# Out:
# 0 0.903954802259887
# 1 0.9154929577464789
# 2 0.9166666666666666
# 3 0.9337016574585635
# 4 0.9126984126984127
# 5 0.8994413407821229
# 6 0.9109947643979057
# 7 0.9063444108761329
# 8 0.8980716253443526
# 9 0.8823529411764706
# 10 0.8619246861924686
# 11 0.707395498392283
# 12 0.7924528301886793
# 13 0.7346938775510204
# 14 0.74375
# 15 0.7348066298342542
# 16 0.6451612903225806
# 17 0.5263157894736842
# 18 0.776536312849162
# 19 0.5230769230769231
# 20 0.9183673469387755
# 21 0.854320987654321
# 22 0.723404255319149
# 23 0.7857142857142857
# 24 0.6227544910179641
# 25 0.6436781609195402
# 26 0.5753424657534246
# 27 0.6175115207373272
# 28 0.4560260586319218
# 29 0.784180790960452
# 30 0.6459854014598541
# 31 0.7306273062730627
# 32 0.7813267813267813
# 33 0.6929460580912863
# 34 0.5942492012779552
# 35 0.7684210526315789
# 36 0.6009615384615384
# 37 0.7163120567375887
# 38 0.5273159144893111
# 39 0.5667447306791569
# 40 0.6646341463414634
# 41 0.4453125
# 42 0.3450834879406308
# 43 0.5349794238683128
# 44 0.6119402985074627
# 45 0.7565982404692082
# 46 0.6983050847457627
# 47 0.6551126516464472
# 48 0.7728813559322034
# 49 0.6791277258566978
# 50 0.6944444444444444
# Dice coeff= 0.7174596702375678
